# %% [markdown]
# # Covid Impact in the City of Atlanta
#
#
# This jupyter notebook will be used to create a heat map of the spread of Covid-19 throughout the state of Georgia
#
#
# ---
#
#
# ## Data sources
# ### Gelocation Data
#     - Atlanta county Geo
# ### Covid-19 Data
#     -Georgia DPH CSV file
# *https://dph.georgia.gov/covid-19-daily-status-report*

# %%
pip install plotly==4.12.0
# Out:
# Requirement already satisfied: plotly==4.12.0 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (4.12.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from plotly==4.12.0) (1.3.3)
# Requirement already satisfied: six in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from plotly==4.12.0) (1.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (0.25.2)
# Requirement already satisfied: pytz>=2017.2 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from pandas) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from pandas) (1.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash
# Out:
# Requirement already satisfied: dash in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (1.17.0)
# Requirement already satisfied: dash-html-components==1.1.1 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from dash) (1.1.1)
# Requirement already satisfied: future in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from dash) (0.18.2)
# Requirement already satisfied: plotly in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from dash) (4.12.0)
# Requirement already satisfied: dash-core-components==1.13.0 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from dash) (1.13.0)
# Requirement already satisfied: dash-renderer==1.8.3 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from dash) (1.8.3)
# Requirement already satisfied: Flask>=1.0.2 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from dash) (1.8.0)
# Requirement already satisfied: dash-table==4.11.0 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from dash) (4.11.0)
# Requirement already satisfied: six in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from plotly->dash) (1.14.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from plotly->dash) (1.3.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from Flask>=1.0.2->dash) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from Flask>=1.0.2->dash) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from Flask>=1.0.2->dash) (2.11.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from Flask>=1.0.2->dash) (1.0.0)
# Requirement already satisfied: brotli in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\zarch\anaconda3\envs\zyenv\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.2->dash) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#load libraries
import pandas as pd
import plotly.express as px
import os
from urllib.request import urlopen
import json

# %% [markdown]
# ##Import county level geojson data from plotly Github

# %%
from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)
ga_counties = {'type': 'FeatureCollection', 'features': []}

# Generate GA specific geojson
for county in counties['features']:
    if county['properties']['STATE'] in ['13']:
        ga_counties['features'].append(county)

# %%
#Pulling dataset from github
txdataurl = 'https://raw.githubusercontent.com/abdulmohammed3/Covid-19_Population_Disparities/master/income_cases.csv'
txdata = pd.read_csv(txdataurl,index_col=0)
txdata = txdata.rename(columns={'County':'fips',})

# %%
#Remove Duplicates
txdata.drop_duplicates(['county_name'],inplace=True)

# %% [markdown]
# ## Choropleth Map Implementetion

# %%
txdata
# Out:
#      OBJECTID      GEOID10   fips                              Area_Name  \
# 0           1  13045910103  13045   Census Tract 9101.03, Carroll County
# 17         18  13113140207  13113   Census Tract 1402.07, Fayette County
# 37         38  13247060404  13247   Census Tract 604.04, Rockdale County
# 52         53  13067030330  13067       Census Tract 303.30, Cobb County
# 172        90  13117130105  13117   Census Tract 1301.05, Forsyth County
# 217       218  13063040411  13063    Census Tract 404.11, Clayton County
# 267       268  13151070403  13151      Census Tract 704.03, Henry County
# 292       293  13015960101  13015    Census Tract 9601.01, Bartow County
# 307       308  13135050319  13135   Census Tract 503.19, Gwinnett County
# 420       354  13217100903  13217    Census Tract 1009.03, Newton County
# 433       434  13121009501  13121      Census Tract 95.01, Fulton County
# 637       447  13139001202  13139        Census Tract 12.02, Hall County
# 673       674  13255160100  13255     Census Tract 1601, Spalding County
# 685       686  13097080102  13097    Census Tract 801.02, Douglas County
# 705       691  13077170602  13077    Census Tract 1706.02, Coweta County
# 725       726  13089980000  13089       Census Tract 9800, DeKalb County
# 870       871  13057090905  13057   Census Tract 909.05, Cherokee County
# 896       886  13297110601  13297    Census Tract 1106.01, Walton County
# 911       912  13013180206  13013    Census Tract 1802.06, Barrow County
# 929       930  13223120104  13223  Census Tract 1201.04, Paulding County
#
#      Total_Population  Total_Population_MOE_2016  Total_households  \
# 0                4824                        361              1836
# 17               5652                        400              2281
# 37               6028                        462              2133
# 52               5959                        313              2029
# 172              2648                        236               831
# 217             12910                       1236              4243
# 267             10299                        790              3318
# 292              1573                        136               634
# 307              6719                        465              1931
# 420              6563                        595              2128
# 433              3730                        369              1674
# 637              6342                        544              1646
# 673              5705                        599              2104
# 685              7554                        869              3176
# 705              8548                        609              3315
# 725                 0                         13                 0
# 870              3886                        353              1778
# 896              4760                        380              1652
# 911              2864                        320              1036
# 929              2649                        228               935
#
#      Total_households_MOE  HH_income_less_35k  HH_income_less_35k_MOE  ...  \
# 0                     131                 570                     160  ...
# 17                    105                 184                      95  ...
# 37                    104                 545                     188  ...
# 52                     49                 225                      99  ...
# 172                    70                 393                      97  ...
# 217                   238                 829                     273  ...
# 267                   210                1080                     258  ...
# 292                    64                 142                      52  ...
# 307                   127                 979                     206  ...
# 420                   141                 769                     212  ...
# 433                   119                 217                      94  ...
# 637                   109                 620                     177  ...
# 673                   159                 768                     219  ...
# 685                   228                1005                     268  ...
# 705                   200                 371                     144  ...
# 725                    13                   0                      32  ...
# 870                   148                 499                     137  ...
# 896                    80                 331                     105  ...
# 911                   104                 329                      98  ...
# 929                    63                 180                      59  ...
#
#      cases  State FIPS code  County FIPS code  population  hospitalization  \
# 0     3353               13                45      120119              180
# 17    2123               13               113      117544              128
# 37    2116               13               247       94960              266
# 52   21814               13                67      790588             1964
# 172   4700               13               117      252507              355
# 217   8168               13                63      304838              689
# 267   6163               13               151      239866              279
# 292   3580               13                15      110771              330
# 307  30383               13               135      971145             2868
# 420   2850               13               217      112354              297
# 433  30926               13               121     1099181             2594
# 637  10605               13               139      206349             1085
# 673   1576               13               255       69110              207
# 685   4078               13                97      151906              464
# 705   2957               13                77      152001              145
# 725  21049               13                89      793154             2309
# 870   7057               13                57      266617              527
# 896   2327               13               297       95814              227
# 911   2579               13                13       86383              263
# 929   3129               13               223      172542              155
#
#      deaths  case rate  death rate  14 day case rate  14 day cases
# 0        75    2791.40       62.44            203.96           245
# 17       57    1806.13       48.49            110.60           130
# 37       40    2228.31       42.12            163.23           155
# 52      454    2759.21       57.43            129.40          1023
# 172      53    1861.33       20.99             94.25           238
# 217     175    2679.46       57.41            144.34           440
# 267     112    2569.35       46.69            149.67           359
# 292      94    3231.89       84.86            336.73           373
# 307     442    3128.58       45.51            153.22          1488
# 420      95    2536.63       84.55            100.57           113
# 433     619    2813.55       56.31            149.93          1648
# 637     173    5139.35       83.84            228.25           471
# 673      62    2280.42       89.71            206.92           143
# 685      72    2684.55       47.40            138.24           210
# 705      63    1945.38       41.45             98.68           150
# 725     397    2653.84       50.05            141.21          1120
# 870     102    2646.87       38.26            189.04           504
# 896      68    2428.66       70.97            158.64           152
# 911      50    2985.54       57.88            208.37           180
# 929      60    1813.47       34.77             92.15           159
#
# [20 rows x 56 columns]

# %%
#Copying dataset to use as df to display map
mapdata = txdata

mapdata = mapdata.sort_values(by=["Area_Name"])

hover_data = ['fips','county_name']

# %% [markdown]
# # Visualizations in the Atlanta Area
#
#
#
# ---

# %% [markdown]
# ## Covid Deaths

# %%
fig = px.choropleth(mapdata,geojson=ga_counties,locations='fips',color='deaths',
                           color_continuous_scale="Viridis",
                           range_color=(0,500),
                           scope="usa",
                           labels={'Label':'label'},hover_name='county_name'
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# ## Covid Cases

# %%
fig = px.choropleth(mapdata,geojson=ga_counties,locations='fips',color='cases',
                           color_continuous_scale="Viridis",
                           range_color=(0,10**4),
                           scope="usa",
                           labels={'Label':'label'},hover_name="county_name"
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# ## Atlanta population density

# %%
fig = px.choropleth(mapdata,geojson=ga_counties,locations='fips',color='population',
                           color_continuous_scale="Viridis",
                           range_color=(0,10**6),
                           scope="usa",
                           labels={'Label':'label'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %% [markdown]
# ## Average income distributiion

# %%
fig = px.choropleth(mapdata,geojson=ga_counties,locations='fips',color='Average_Per_capita_Income_MOE',
                           color_continuous_scale="Viridis",
                           range_color=(0,10**4),
                           scope="usa",
                           labels={'Label':'label'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
